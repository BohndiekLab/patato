# %%
import patato as pat
import matplotlib.pyplot as plt

pa_so2 = pat.PAData.from_hdf5("/Users/else01/Temporary PATATO Data Share/patato-example-data/In Vivo Data/Scan_9.hdf5")
recon = pa_so2.get_scan_reconstructions()["Reference Backprojection", "0"]
so2 = pa_so2.get_scan_so2()["Reference Backprojection", "0"]

roi = pa_so2.get_rois()["tumour_right", "0"]

recon.imshow(scale_kwargs=dict(font_properties=dict(size="large")))
so2.imshow(roi_mask=roi, scalebar=False)
plt.show()
